# %% [markdown]
# <a href="https://colab.research.google.com/github/berasurupa-hub/js-hindi-youtube/blob/main/Accident_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/accident/accident_prediction_india.csv')
df
# Out:
#              State Name City Name  Year      Month Day of Week Time of Day  \
# 0     Jammu and Kashmir   Unknown  2021        May      Monday        1:46
# 1         Uttar Pradesh   Lucknow  2018    January   Wednesday       21:30
# 2          Chhattisgarh   Unknown  2023        May   Wednesday        5:37
# 3         Uttar Pradesh   Lucknow  2020       June    Saturday        0:31
# 4                Sikkim   Unknown  2021     August    Thursday       11:21
# ...                 ...       ...   ...        ...         ...         ...
# 2995         Tamil Nadu   Chennai  2021    January      Sunday        1:15
# 2996        Uttarakhand   Unknown  2018       July      Sunday       10:12
# 2997          Meghalaya   Unknown  2021    January    Thursday       19:34
# 2998          Meghalaya   Unknown  2023       June      Sunday       20:54
# 2999  Arunachal Pradesh   Unknown  2020  September      Monday        7:19
#
#      Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0              Serious                            5                 Cycle
# 1                Minor                            5                 Truck
# 2                Minor                            5            Pedestrian
# 3                Minor                            3                   Bus
# 4                Minor                            5                 Cycle
# ...                ...                          ...                   ...
# 2995             Minor                            5                 Truck
# 2996             Fatal                            3                   Car
# 2997             Minor                            2           Two-Wheeler
# 2998             Fatal                            1                 Cycle
# 2999             Fatal                            5                 Cycle
#
#       Number of Casualties  ...         Road Type      Road Condition  \
# 0                        0  ...  National Highway                 Wet
# 1                        5  ...        Urban Road                 Dry
# 2                        6  ...  National Highway  Under Construction
# 3                       10  ...     State Highway                 Dry
# 4                        7  ...        Urban Road                 Wet
# ...                    ...  ...               ...                 ...
# 2995                     4  ...  National Highway                 Wet
# 2996                     3  ...        Urban Road  Under Construction
# 2997                     8  ...  National Highway                 Dry
# 2998                     9  ...        Urban Road  Under Construction
# 2999                     1  ...  National Highway  Under Construction
#
#      Lighting Conditions Traffic Control Presence Speed Limit (km/h)  \
# 0                   Dark                    Signs                 61
# 1                   Dusk                    Signs                 92
# 2                   Dawn                    Signs                120
# 3                   Dark                  Signals                 76
# 4                   Dusk                    Signs                115
# ...                  ...                      ...                ...
# 2995                Dark                    Signs                 74
# 2996            Daylight                      NaN                 86
# 2997                Dark                    Signs                 47
# 2998            Daylight                    Signs                 60
# 2999            Daylight                      NaN                 40
#
#      Driver Age  Driver Gender  Driver License Status Alcohol Involvement  \
# 0            66           Male                    NaN                 Yes
# 1            60           Male                    NaN                 Yes
# 2            26         Female                    NaN                  No
# 3            34         Female                  Valid                 Yes
# 4            30           Male                    NaN                  No
# ...         ...            ...                    ...                 ...
# 2995         43           Male                Expired                 Yes
# 2996         23         Female                    NaN                 Yes
# 2997         57         Female                  Valid                 Yes
# 2998         28         Female                Expired                 Yes
# 2999         66           Male                    NaN                 Yes
#
#      Accident Location Details
# 0                        Curve
# 1                Straight Road
# 2                       Bridge
# 3                Straight Road
# 4                 Intersection
# ...                        ...
# 2995              Intersection
# 2996              Intersection
# 2997              Intersection
# 2998                    Bridge
# 2999                    Bridge
#
# [3000 rows x 22 columns]

# %%
df.head()
# Out:
#           State Name City Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir   Unknown  2021      May      Monday        1:46
# 1      Uttar Pradesh   Lucknow  2018  January   Wednesday       21:30
# 2       Chhattisgarh   Unknown  2023      May   Wednesday        5:37
# 3      Uttar Pradesh   Lucknow  2020     June    Saturday        0:31
# 4             Sikkim   Unknown  2021   August    Thursday       11:21
#
#   Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0           Serious                            5                 Cycle
# 1             Minor                            5                 Truck
# 2             Minor                            5            Pedestrian
# 3             Minor                            3                   Bus
# 4             Minor                            5                 Cycle
#
#    Number of Casualties  ...         Road Type      Road Condition  \
# 0                     0  ...  National Highway                 Wet
# 1                     5  ...        Urban Road                 Dry
# 2                     6  ...  National Highway  Under Construction
# 3                    10  ...     State Highway                 Dry
# 4                     7  ...        Urban Road                 Wet
#
#   Lighting Conditions Traffic Control Presence Speed Limit (km/h) Driver Age  \
# 0                Dark                    Signs                 61         66
# 1                Dusk                    Signs                 92         60
# 2                Dawn                    Signs                120         26
# 3                Dark                  Signals                 76         34
# 4                Dusk                    Signs                115         30
#
#    Driver Gender  Driver License Status Alcohol Involvement  \
# 0           Male                    NaN                 Yes
# 1           Male                    NaN                 Yes
# 2         Female                    NaN                  No
# 3         Female                  Valid                 Yes
# 4           Male                    NaN                  No
#
#   Accident Location Details
# 0                     Curve
# 1             Straight Road
# 2                    Bridge
# 3             Straight Road
# 4              Intersection
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#              State Name City Name  Year      Month Day of Week Time of Day  \
# 2995         Tamil Nadu   Chennai  2021    January      Sunday        1:15
# 2996        Uttarakhand   Unknown  2018       July      Sunday       10:12
# 2997          Meghalaya   Unknown  2021    January    Thursday       19:34
# 2998          Meghalaya   Unknown  2023       June      Sunday       20:54
# 2999  Arunachal Pradesh   Unknown  2020  September      Monday        7:19
#
#      Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 2995             Minor                            5                 Truck
# 2996             Fatal                            3                   Car
# 2997             Minor                            2           Two-Wheeler
# 2998             Fatal                            1                 Cycle
# 2999             Fatal                            5                 Cycle
#
#       Number of Casualties  ...         Road Type      Road Condition  \
# 2995                     4  ...  National Highway                 Wet
# 2996                     3  ...        Urban Road  Under Construction
# 2997                     8  ...  National Highway                 Dry
# 2998                     9  ...        Urban Road  Under Construction
# 2999                     1  ...  National Highway  Under Construction
#
#      Lighting Conditions Traffic Control Presence Speed Limit (km/h)  \
# 2995                Dark                    Signs                 74
# 2996            Daylight                      NaN                 86
# 2997                Dark                    Signs                 47
# 2998            Daylight                    Signs                 60
# 2999            Daylight                      NaN                 40
#
#      Driver Age  Driver Gender  Driver License Status Alcohol Involvement  \
# 2995         43           Male                Expired                 Yes
# 2996         23         Female                    NaN                 Yes
# 2997         57         Female                  Valid                 Yes
# 2998         28         Female                Expired                 Yes
# 2999         66           Male                    NaN                 Yes
#
#      Accident Location Details
# 2995              Intersection
# 2996              Intersection
# 2997              Intersection
# 2998                    Bridge
# 2999                    Bridge
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State Name                   3000 non-null   object
#  1   City Name                    3000 non-null   object
#  2   Year                         3000 non-null   int64
#  3   Month                        3000 non-null   object
#  4   Day of Week                  3000 non-null   object
#  5   Time of Day                  3000 non-null   object
#  6   Accident Severity            3000 non-null   object
#  7   Number of Vehicles Involved  3000 non-null   int64
#  8   Vehicle Type Involved        3000 non-null   object
#  9   Number of Casualties         3000 non-null   int64
#  10  Number of Fatalities         3000 non-null   int64
#  11  Weather Conditions           3000 non-null   object
#  12  Road Type                    3000 non-null   object
#  13  Road Condition               3000 non-null   object
#  14  Lighting Conditions          3000 non-null   object
#  15  Traffic Control Presence     2284 non-null   object
#  16  Speed Limit (km/h)           3000 non-null   int64
#  17  Driver Age                   3000 non-null   int64
#  18  Driver Gender                3000 non-null   object
#  19  Driver License Status        2025 non-null   object
#  20  Alcohol Involvement          3000 non-null   object
#  21  Accident Location Details    3000 non-null   object
# dtypes: int64(6), object(16)
# memory usage: 515.8+ KB

# %%
df.shape
# Out:
# (3000, 22)

# %%
df.describe()
# Out:
#               Year  Number of Vehicles Involved  Number of Casualties  \
# count  3000.000000                  3000.000000           3000.000000
# mean   2020.530000                     2.996000              5.066000
# std       1.683858                     1.428285              3.214097
# min    2018.000000                     1.000000              0.000000
# 25%    2019.000000                     2.000000              2.000000
# 50%    2021.000000                     3.000000              5.000000
# 75%    2022.000000                     4.000000              8.000000
# max    2023.000000                     5.000000             10.000000
#
#        Number of Fatalities  Speed Limit (km/h)  Driver Age
# count           3000.000000         3000.000000  3000.00000
# mean               2.455333           74.940667    44.17700
# std                1.717650           26.765088    15.40286
# min                0.000000           30.000000    18.00000
# 25%                1.000000           51.000000    31.00000
# 50%                2.000000           75.000000    45.00000
# 75%                4.000000           99.000000    57.00000
# max                5.000000          120.000000    70.00000

# %%
df.isnull().sum()
# Out:
# State Name                       0
# City Name                        0
# Year                             0
# Month                            0
# Day of Week                      0
# Time of Day                      0
# Accident Severity                0
# Number of Vehicles Involved      0
# Vehicle Type Involved            0
# Number of Casualties             0
# Number of Fatalities             0
# Weather Conditions               0
# Road Type                        0
# Road Condition                   0
# Lighting Conditions              0
# Traffic Control Presence       716
# Speed Limit (km/h)               0
# Driver Age                       0
# Driver Gender                    0
# Driver License Status          975
# Alcohol Involvement              0
# Accident Location Details        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Accident Severity'].value_counts(normalize= True)
# Out:
# Accident Severity
# Minor      0.344667
# Fatal      0.328333
# Serious    0.327000
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,5))
sns.countplot(x=df['Accident Severity'])
plt.title('Distribtution of Accident Severity', fontsize=15, color = 'green')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Accident Severity'], hue=df['Driver Gender'], palette='Reds')
plt.title('Distribtution of Accident Severity vs Driver Gender', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,10))
sns.countplot(x=df['Vehicle Type Involved'], palette='tab10')
plt.title("Vehicle Types Involved in Accidents")
plt.xlabel("Vehicle Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2859533268.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Vehicle Type Involved'], palette='tab10')

# %%
plt.figure(figsize=(10,5))
top_vehicles = df["Vehicle Type Involved"].value_counts().nlargest(10)
sns.barplot(x=top_vehicles.index, y=top_vehicles.values, palette="rocket_r")
plt.xticks(rotation=45)
plt.title("Top 10 Vehicle Types Involved in Accidents")
plt.show()
# Out:
# /tmp/ipython-input-576755914.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vehicles.index, y=top_vehicles.values, palette="rocket_r")

# %%
state_counts = df['State Name'].value_counts().head(15)
plt.figure(figsize=(8,8))
plt.pie(state_counts, labels=state_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 10 States by Number of Road Accidents', fontsize=16, color='blue')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Light Condition  VS Road Condition', fontsize=15)
sns.countplot(x=df['Lighting Conditions'], hue=df['Road Condition'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Weather Conditions'], hue=df['Accident Severity'], palette='cividis')
plt.title("Impact of Weather Conditions on Accident Severity")
plt.xlabel("Weather Condition")
plt.ylabel("Accident Count")
plt.xticks(rotation=30)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Road Type  VS Accident Severity', fontsize=15)
sns.countplot(x=df['Road Type'],hue=df['Accident Severity'], palette='bright')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Vehicle Type Involved VS Accident Severity', fontsize=15)
sns.countplot(x=df['Vehicle Type Involved'],hue=df['Accident Severity'], palette='summer')
plt.show()

# %%
df['Vehicle Type Involved'].value_counts()
# Out:
# Vehicle Type Involved
# Truck            449
# Auto-Rickshaw    449
# Bus              442
# Two-Wheeler      427
# Cycle            421
# Pedestrian       419
# Car              393
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df['Year'].value_counts().sort_index().plot(kind='line', marker='o')
plt.title("Year-wise Accident Trend")
plt.xlabel("Year")
plt.ylabel("Accident Count")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Distribtution of Accident Severity Over Month', fontsize=15)
sns.lineplot(x=df['Month'], y=df['Accident Severity'], color='tomato')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Distribtution of Accident Severity Over Day of Week', fontsize=15)
sns.lineplot(x=df['Day of Week'], y=df['Accident Severity'], color='skyblue')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Distribtution of Accident Severity Over Year', fontsize=15)
sns.lineplot(x=df['Year'], y=df['Accident Severity'], color='orange')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Corrlation of Numerical Columns', fontsize=20, color = 'red')
num_df = df.select_dtypes(include=['number'])
sns.heatmap(num_df.corr(), cmap='copper', annot=True)
plt.show()
